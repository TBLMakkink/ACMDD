# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
pip install --upgrade xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (2.0.1)

# %%
df = pd.read_excel('data.xls')

# %%
df.describe()
# Out:
#           cell count  migration score  biological replicate  \
# count     315.000000       315.000000            315.000000
# mean    98029.471710         1.522320              2.000000
# std    111412.765609         1.833875              0.817796
# min    -25652.958231        -0.447149              1.000000
# 25%     42858.984183         0.568913              1.000000
# 50%     72331.955007         1.001566              2.000000
# 75%     90270.495558         1.787471              3.000000
# max    649911.199232        11.346342              3.000000
#
#        technical replicate
# count           315.000000
# mean              2.000000
# std               0.817796
# min               1.000000
# 25%               1.000000
# 50%               2.000000
# 75%               3.000000
# max               3.000000

# %%
df.head()
# Out:
#       cell count  migration score treatment    line  biological replicate  \
# 0   62149.302073         4.002821         A  line 1                     1
# 1  107357.676108         0.735643         B  line 1                     1
# 2   31153.448211         0.425228         C  line 1                     1
# 3  209276.555352         1.686360         D  line 1                     1
# 4  426578.077249         0.127881         E  line 1                     1
#
#    technical replicate
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
for i in df['line'].unique():
    fig, ax = plt.subplots(1,2)
    sns.barplot(data=df[df['line']==i], y='cell count', x='treatment', hue='biological replicate', ax=ax[0])
    sns.barplot(data=df[df['line']==i], y='migration score', x='treatment', hue='biological replicate', ax=ax[1])
    ax[0].set_title('Proliferation')
    ax[1].set_title('Migration')
    plt.show()

# %%
#save plot
plt.savefig('Images/Proliferation and Migration')

# %%
sns.barplot(data=df, x='line', y='cell count', hue='treatment')

# %%
#save plot
plt.savefig('Images/Treatment Cell Count')

# %%
sns.barplot(data=df, x='line', y='migration score', hue='treatment')

# %%
#save plot
plt.savefig('Images/Treatment Migration Score')

# %%
Control_value = df[(df['line']=='line 1') & (df['treatment']=='control')].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
df['cell count'] = df['cell count']/Control_value['cell count']-1
df['migration score'] = df['migration score']/Control_value['migration score']-1

# %%
sns.barplot(data=df, x='line', y='cell count', hue='treatment')
plt.title("Proliferation")
# Out:
# Text(0.5, 1.0, 'Proliferation')

# %%
#save plot
plt.savefig('Images/Cell count Proliferation')

# %%
sns.barplot(data=df, x='line', y='migration score', hue='treatment')
plt.title("Migration")
# Out:
# Text(0.5, 1.0, 'Migration')

# %%
#save plot
plt.savefig('Images/Migration Score Migration')

# %%
pair_df = df[['cell count', 'migration score', 'treatment', 'line']]
sns.pairplot(pair_df, hue='treatment')

# %%
#save plot
plt.savefig('Images/Treatment Plots')

# %%
sns.pairplot(pair_df, hue='line')

# %%
#save plot
plt.savefig('Images/Line plots')
